# %% [markdown]
# <a href="https://colab.research.google.com/github/Oliver-NG23/First-Proyect/blob/main/Primer_Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="text-align: center;">Global Air Quality and Respiratory Health Outcomes
# </h1>
#
# ---

# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://continentalhospitals.com/images/blogs/a6981b0362f0d812a9d63ffebc14d7cc.jpg" alt="IMAGEN" width="40%"/>
# </div>
#
#
# [Dataset](https://www.kaggle.com/datasets/youssefelebiary/air-quality-2024)

# %% [markdown]
# ### **LOADING DATA AND OVERVIEW**

# %%
#GENERAL LIBRARIES
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
#LOADING THE DATA
from google.colab import files
import zipfile
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f6bc625e-d7d7-4008-9980-d2c46c95cf3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6bc625e-d7d7-4008-9980-d2c46c95cf3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
archivo_zip = list(uploaded.keys())[0]
carpeta_destino = 'carpeta_extraida/'
with zipfile.ZipFile(archivo_zip, 'r') as zip_ref:
    zip_ref.extractall(carpeta_destino)

# %%
air_quality = pd.read_csv('carpeta_extraida/Air_Quality.csv')
df = air_quality.copy()
# Out:
#                         Date      City     CO  CO2   NO2  SO2    O3  PM2.5  \
# 0  2024-01-01 00:00:00+00:00  Brasilia  323.0  NaN  23.8  2.8  42.0   12.0
# 1  2024-01-01 01:00:00+00:00  Brasilia  318.0  NaN  21.9  2.7  40.0   12.5
# 2  2024-01-01 02:00:00+00:00  Brasilia  309.0  NaN  19.2  2.6  39.0   12.1
# 3  2024-01-01 03:00:00+00:00  Brasilia  295.0  NaN  16.3  2.4  38.0   11.4
# 4  2024-01-01 04:00:00+00:00  Brasilia  270.0  NaN  13.0  2.1  40.0   10.2
#
#    PM10        AQI
# 0  17.1  16.800000
# 1  17.9  16.000000
# 2  17.3  15.599999
# 3  16.2  15.200000
# 4  14.6  16.000000

# %%
#Summary table
df.describe()
# Out:
#                  CO          CO2           NO2           SO2            O3  \
# count  52704.000000  9648.000000  52704.000000  52704.000000  52704.000000
# mean     258.258121   462.348259     24.102998     12.569869     60.025729
# std      159.589953    33.769009     19.363443     17.266623     38.217348
# min       52.000000   434.000000      0.000000      0.000000      0.000000
# 25%      159.000000   445.000000      9.700000      2.300000     35.000000
# 50%      213.000000   453.000000     18.900000      5.700000     54.000000
# 75%      306.000000   467.000000     33.400000     16.800000     78.000000
# max     2045.000000   884.000000    165.900000    239.700000    349.000000
#
#               PM2.5          PM10           AQI
# count  52704.000000  52704.000000  52704.000000
# mean      17.689931     35.643143     41.349339
# std       15.670075     48.444774     26.626149
# min        0.100000      0.100000      4.450000
# 25%        6.900000     10.200000     22.800000
# ...

# %% [markdown]
# From the summary table, we can note:
# -  We have null values that we drop from the dataset

# %%
df_new=df.dropna()
df_new.describe()
# Out:
#                 CO          CO2          NO2          SO2           O3  \
# count  9648.000000  9648.000000  9648.000000  9648.000000  9648.000000
# mean    288.763889   462.348259    27.877394    15.921559    51.407338
# std     169.797270    33.769009    21.404029    22.578019    31.434428
# min      79.000000   434.000000     0.200000     0.300000     0.000000
# 25%     175.000000   445.000000    10.300000     2.600000    28.000000
# 50%     241.000000   453.000000    22.400000     6.300000    50.000000
# 75%     356.000000   467.000000    41.900000    20.300000    72.000000
# max    2045.000000   884.000000   114.700000   219.300000   198.000000
#
#              PM2.5         PM10          AQI
# count  9648.000000  9648.000000  9648.000000
# mean     16.853379    25.580732    39.263667
# std      12.292554    23.274004    19.230844
# min       0.500000     0.500000     8.849999
# 25%       7.500000     9.500000    23.400000
# 50%      12.950000    17.200000    32.400000
# ...
